# %% [markdown]
# <a href="https://colab.research.google.com/github/M-PRERNA/MACHINE-LEARNING/blob/main/Cats_and_Dogs_without_image_augmenatation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # The cats vs dogs classification without image augmentation

# %% [markdown]
# -The data set in actual contains only 25000 images, but this would take a lot of time to train and test the models with such a large dataset.
#
# -Thus we make use of only 2000 training images and 1000 test images

# %% [markdown]
# ## importing packages

# %%
import os
import logging
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
logger = tf.get_logger()
logger.setLevel(logging.ERROR)

# %% [markdown]
# # Loading the data

# %% [markdown]
# Earlier we used the tensorflow datasets. Now we'd be using the class `tf.keras.preprocessing.image.ImageDataGenerator` which will read data from disk. We therefore need to directly download Dogs vs. Cats from a URL and unzip it to the Colab filesystem.

# %%
_URL = 'https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip'
zip_dir = tf.keras.utils.get_file('cats_and_dogs_filterted.zip', origin=_URL, extract=True)
# Out:
# Downloading data from https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# 68608000/68606236 [==============================] - 1s 0us/step

# %% [markdown]
# listing the directories with the following terminal commands

# %%
zip_dir_base = os.path.dirname(zip_dir)
# !find $zip_dir_base -type d -print
# Out:
# /root/.keras/datasets
# /root/.keras/datasets/cats_and_dogs_filtered
# /root/.keras/datasets/cats_and_dogs_filtered/validation
# /root/.keras/datasets/cats_and_dogs_filtered/validation/dogs
# /root/.keras/datasets/cats_and_dogs_filtered/validation/cats
# /root/.keras/datasets/cats_and_dogs_filtered/train
# /root/.keras/datasets/cats_and_dogs_filtered/train/dogs
# /root/.keras/datasets/cats_and_dogs_filtered/train/cats

# %% [markdown]
# assigning variables with the proper file path with training and validation test sets

# %%
base_dir = os.path.join(os.path.dirname(zip_dir),'cats_and_dogs_filtered')
train_dir = os.path.join(base_dir,'train')
validation_dir = os.path.join(base_dir,'validation')

# %%
# directory with training cats pictures
train_cats_dir = os.path.join(train_dir,'cats')
# diretory with training dogs pictures
train_dogs_dir = os.path.join(train_dir,'dogs')
# directory with validation cats pics
validation_cats_dir = os.path.join(validation_dir,'cats')
# directory with validation dogs pic
validation_dogs_dir = os.path.join(validation_dir,'dogs')

# %% [markdown]
# # Understanding our data

# %% [markdown]
# number of cats and dogs images within the training and validation directory

# %%
num_cats_tr = len(os.listdir(train_cats_dir))
num_dogs_tr = len(os.listdir(train_dogs_dir))

num_cats_val = len(os.listdir(validation_cats_dir))
num_dogs_val = len(os.listdir(validation_dogs_dir))

total_train = num_cats_tr + num_dogs_tr
total_val = num_cats_val + num_dogs_val

# %%
print('total training cat images:', num_cats_tr)
print('total training dog images:', num_dogs_tr)

print('total validation cat images:', num_cats_val)
print('total validation dog images:', num_dogs_val)
print("--")
print("Total training images:", total_train)
print("Total validation images:", total_val)
# Out:
# total training cat images: 1000
# total training dog images: 1000
# total validation cat images: 500
# total validation dog images: 500
# --
# Total training images: 2000
# Total validation images: 1000

# %% [markdown]
# # setting model parameters

# %%
BATCH_SIZE = 100  # Number of training examples to process before updating our models variables
IMG_SHAPE  = 150  # Our training data consists of images with width of 150 pixels and height of 150 pixels

# %% [markdown]
# # Data preparation

# %% [markdown]
# Images must be formatted into appropriately pre-processed floating point tensors before being fed into the network. The steps involved in preparing these images are:
#
# 1. Read images from the disk
# 2. Decode contents of these images and convert it into proper grid format as per their RGB content
# 3. Convert them into floating point tensors
# 4. Rescale the tensors from values between 0 and 255 to values between 0 and 1, as neural networks prefer to deal with small input values.
# **Fortunately, all these tasks can be done using the class tf.keras.preprocessing.image.ImageDataGenerator.**
#
# We can set this up in a couple of lines of code.

# %%
train_image_generator = ImageDataGenerator(rescale=1./255)
validation_image_generator = ImageDataGenerator(rescale=1./255)

# %% [markdown]
# After defining our generators for training and validation images, flow_from_directory method will load images from the disk, apply rescaling, and resize them using single line of code.

# %%
train_data_gen = train_image_generator.flow_from_directory(batch_size=BATCH_SIZE,
                                                           directory=train_dir,
                                                           shuffle=True,
                                                           target_size=(IMG_SHAPE,IMG_SHAPE), #(150,150)
                                                           class_mode='binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %%
val_data_gen = validation_image_generator.flow_from_directory(batch_size=BATCH_SIZE,
                                                              directory=validation_dir,
                                                              shuffle=False,
                                                              target_size=(IMG_SHAPE,IMG_SHAPE), #(150,150)
                                                              class_mode='binary')
# Out:
# Found 1000 images belonging to 2 classes.

# %% [markdown]
# # Visualizing training images

# %% [markdown]
# We can visualize our training images by getting a batch of images from the training generator, and then plotting a few of them using matplotlib.

# %%
sample_training_images, _ = next(train_data_gen)

# %%
# This function will plot images in the form of a grid with 1 row and 5 columns where images are placed in each column.
def plotImages(images_arr):
    fig, axes = plt.subplots(1, 5, figsize=(20,20))
    axes = axes.flatten()
    for img, ax in zip(images_arr, axes):
        ax.imshow(img)
    plt.tight_layout()
    plt.show()

# %%
plotImages(sample_training_images[:5])  # Plot images 0-4

# %% [markdown]
# # Model creation

# %% [markdown]
# # Defining the model

# %% [markdown]
# The model consists of four convolution blocks with a max pool layer in each of them. Then we have a fully connected layer with 512 units, with a relu activation function. The model will output class probabilities for two classes — dogs and cats — using softmax.

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(32,(3,3), activation='relu',input_shape=(150,150,3)),
  tf.keras.layers.MaxPooling2D(2,2),

  tf.keras.layers.Conv2D(64,(3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),

  tf.keras.layers.Conv2D(128,(3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),  

  tf.keras.layers.Conv2D(128,(3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),

  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(512, activation='relu'),
  tf.keras.layers.Dense(2,activation='softmax')
])

# %% [markdown]
# # Compiling the model

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 34, 34, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 17, 17, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 15, 15, 128)       147584
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6272)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               3211776
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 3,453,634
# Trainable params: 3,453,634
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Training the model

# %% [markdown]
# Since our batches are coming from a generator (ImageDataGenerator), we'll use fit_generator instead of fit.

# %%
EPOCHS = 100
history = model.fit_generator(
    train_data_gen,
    steps_per_epoch=int(np.ceil(total_train / float(BATCH_SIZE))),
    epochs=EPOCHS,
    validation_data=val_data_gen,
    validation_steps=int(np.ceil(total_val / float(BATCH_SIZE)))
)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 20/20 [==============================] - 11s 518ms/step - loss: 0.0641 - accuracy: 0.9739 - val_loss: 1.4426 - val_accuracy: 0.7300
# Epoch 2/100
# 20/20 [==============================] - 10s 511ms/step - loss: 0.0312 - accuracy: 0.9911 - val_loss: 1.6031 - val_accuracy: 0.7320
# Epoch 3/100
# 20/20 [==============================] - 10s 501ms/step - loss: 0.0142 - accuracy: 0.9954 - val_loss: 1.7012 - val_accuracy: 0.7260
# Epoch 4/100
# 20/20 [==============================] - 10s 503ms/step - loss: 0.0151 - accuracy: 0.9961 - val_loss: 1.7708 - val_accuracy: 0.7300
# Epoch 5/100
# 20/20 [==============================] - 10s 502ms/step - loss: 0.0059 - accuracy: 0.9989 - val_loss: 1.9331 - val_accuracy: 0.7240
# Epoch 6/100
# 20/20 [==============================] - 10s 499ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.8640 - val_accuracy: 0.7270
# Epoch 7/100
# 20/20 [==============================] - 10s 501ms/step - loss: 6.0577e-04 - accuracy: 1.0000 - val_loss: 1.9074 - val_accuracy: 0.7370
# Epoch 8/100
# 20/20 [==============================] - 10s 501ms/step - loss: 3.1076e-04 - accuracy: 1.0000 - val_loss: 1.9652 - val_accuracy: 0.7320
# Epoch 9/100
# 20/20 [==============================] - 10s 499ms/step - loss: 2.0891e-04 - accuracy: 1.0000 - val_loss: 1.9679 - val_accuracy: 0.7340
# Epoch 10/100
# 20/20 [==============================] - 10s 498ms/step - loss: 1.6716e-04 - accuracy: 1.0000 - val_loss: 1.9921 - val_accuracy: 0.7350
# Epoch 11/100
# 20/20 [==============================] - 10s 503ms/step - loss: 1.1764e-04 - accuracy: 1.0000 - val_loss: 2.0137 - val_accuracy: 0.7360
# Epoch 12/100
# 20/20 [==============================] - 10s 502ms/step - loss: 9.6864e-05 - accuracy: 1.0000 - val_loss: 2.0365 - val_accuracy: 0.7370
# Epoch 13/100
# 20/20 [==============================] - 10s 504ms/step - loss: 1.0922e-04 - accuracy: 1.0000 - val_loss: 2.0518 - val_accuracy: 0.7370
# Epoch 14/100
# 20/20 [==============================] - 10s 504ms/step - loss: 9.1142e-05 - accuracy: 1.0000 - val_loss: 2.0717 - val_accuracy: 0.7370
# Epoch 15/100
# 20/20 [==============================] - 10s 495ms/step - loss: 6.7491e-05 - accuracy: 1.0000 - val_loss: 2.0821 - val_accuracy: 0.7390
# Epoch 16/100
# 20/20 [==============================] - 10s 499ms/step - loss: 5.7014e-05 - accuracy: 1.0000 - val_loss: 2.1014 - val_accuracy: 0.7400
# Epoch 17/100
# 20/20 [==============================] - 10s 502ms/step - loss: 5.6846e-05 - accuracy: 1.0000 - val_loss: 2.1110 - val_accuracy: 0.7400
# Epoch 18/100
# 20/20 [==============================] - 10s 504ms/step - loss: 5.3458e-05 - accuracy: 1.0000 - val_loss: 2.1288 - val_accuracy: 0.7420
# Epoch 19/100
# 20/20 [==============================] - 10s 500ms/step - loss: 5.1174e-05 - accuracy: 1.0000 - val_loss: 2.1393 - val_accuracy: 0.7390
# Epoch 20/100
# 20/20 [==============================] - 10s 502ms/step - loss: 4.2590e-05 - accuracy: 1.0000 - val_loss: 2.1553 - val_accuracy: 0.7430
# Epoch 21/100
# 20/20 [==============================] - 10s 498ms/step - loss: 3.9367e-05 - accuracy: 1.0000 - val_loss: 2.1614 - val_accuracy: 0.7420
# Epoch 22/100
# 20/20 [==============================] - 10s 493ms/step - loss: 3.1957e-05 - accuracy: 1.0000 - val_loss: 2.1736 - val_accuracy: 0.7430
# Epoch 23/100
# 20/20 [==============================] - 10s 494ms/step - loss: 3.0593e-05 - accuracy: 1.0000 - val_loss: 2.1913 - val_accuracy: 0.7490
# Epoch 24/100
# 20/20 [==============================] - 10s 501ms/step - loss: 2.4794e-05 - accuracy: 1.0000 - val_loss: 2.2150 - val_accuracy: 0.7450
# Epoch 25/100
# 20/20 [==============================] - 10s 498ms/step - loss: 2.3824e-05 - accuracy: 1.0000 - val_loss: 2.2331 - val_accuracy: 0.7470
# Epoch 26/100
# 20/20 [==============================] - 10s 498ms/step - loss: 2.0312e-05 - accuracy: 1.0000 - val_loss: 2.2558 - val_accuracy: 0.7420
# Epoch 27/100
# 20/20 [==============================] - 10s 500ms/step - loss: 1.5454e-05 - accuracy: 1.0000 - val_loss: 2.2812 - val_accuracy: 0.7460
# Epoch 28/100
# 20/20 [==============================] - 10s 496ms/step - loss: 1.4617e-05 - accuracy: 1.0000 - val_loss: 2.2984 - val_accuracy: 0.7470
# Epoch 29/100
# 20/20 [==============================] - 10s 496ms/step - loss: 1.2472e-05 - accuracy: 1.0000 - val_loss: 2.3225 - val_accuracy: 0.7470
# Epoch 30/100
# 20/20 [==============================] - 10s 497ms/step - loss: 1.1760e-05 - accuracy: 1.0000 - val_loss: 2.3163 - val_accuracy: 0.7400
# Epoch 31/100
# 20/20 [==============================] - 10s 500ms/step - loss: 1.0527e-05 - accuracy: 1.0000 - val_loss: 2.3412 - val_accuracy: 0.7430
# Epoch 32/100
# 20/20 [==============================] - 10s 497ms/step - loss: 1.0258e-05 - accuracy: 1.0000 - val_loss: 2.3566 - val_accuracy: 0.7430
# Epoch 33/100
# 20/20 [==============================] - 10s 493ms/step - loss: 8.9842e-06 - accuracy: 1.0000 - val_loss: 2.3725 - val_accuracy: 0.7430
# Epoch 34/100
# 20/20 [==============================] - 10s 497ms/step - loss: 8.4134e-06 - accuracy: 1.0000 - val_loss: 2.3799 - val_accuracy: 0.7440
# Epoch 35/100
# 20/20 [==============================] - 10s 495ms/step - loss: 7.0050e-06 - accuracy: 1.0000 - val_loss: 2.4047 - val_accuracy: 0.7460
# Epoch 36/100
# 20/20 [==============================] - 10s 497ms/step - loss: 6.7890e-06 - accuracy: 1.0000 - val_loss: 2.4111 - val_accuracy: 0.7450
# Epoch 37/100
# 20/20 [==============================] - 10s 502ms/step - loss: 5.7996e-06 - accuracy: 1.0000 - val_loss: 2.4248 - val_accuracy: 0.7450
# Epoch 38/100
# 20/20 [==============================] - 10s 502ms/step - loss: 5.6832e-06 - accuracy: 1.0000 - val_loss: 2.4381 - val_accuracy: 0.7440
# Epoch 39/100
# 20/20 [==============================] - 10s 499ms/step - loss: 5.0914e-06 - accuracy: 1.0000 - val_loss: 2.4454 - val_accuracy: 0.7460
# Epoch 40/100
# 20/20 [==============================] - 10s 497ms/step - loss: 4.5003e-06 - accuracy: 1.0000 - val_loss: 2.4547 - val_accuracy: 0.7440
# Epoch 41/100
# 20/20 [==============================] - 10s 499ms/step - loss: 4.6420e-06 - accuracy: 1.0000 - val_loss: 2.4573 - val_accuracy: 0.7430
# Epoch 42/100
# 20/20 [==============================] - 10s 495ms/step - loss: 4.3482e-06 - accuracy: 1.0000 - val_loss: 2.4689 - val_accuracy: 0.7450
# Epoch 43/100
# 20/20 [==============================] - 10s 501ms/step - loss: 4.1272e-06 - accuracy: 1.0000 - val_loss: 2.4793 - val_accuracy: 0.7460
# Epoch 44/100
# 20/20 [==============================] - 10s 505ms/step - loss: 3.8770e-06 - accuracy: 1.0000 - val_loss: 2.4851 - val_accuracy: 0.7460
# Epoch 45/100
# 20/20 [==============================] - 10s 501ms/step - loss: 3.5739e-06 - accuracy: 1.0000 - val_loss: 2.4924 - val_accuracy: 0.7450
# Epoch 46/100
# 20/20 [==============================] - 10s 497ms/step - loss: 3.2792e-06 - accuracy: 1.0000 - val_loss: 2.5022 - val_accuracy: 0.7470
# Epoch 47/100
# 20/20 [==============================] - 10s 499ms/step - loss: 2.8898e-06 - accuracy: 1.0000 - val_loss: 2.5114 - val_accuracy: 0.7450
# Epoch 48/100
# 20/20 [==============================] - 10s 500ms/step - loss: 3.0373e-06 - accuracy: 1.0000 - val_loss: 2.5153 - val_accuracy: 0.7450
# Epoch 49/100
# 20/20 [==============================] - 10s 497ms/step - loss: 2.9617e-06 - accuracy: 1.0000 - val_loss: 2.5240 - val_accuracy: 0.7440
# Epoch 50/100
# 20/20 [==============================] - 10s 497ms/step - loss: 2.5118e-06 - accuracy: 1.0000 - val_loss: 2.5295 - val_accuracy: 0.7450
# Epoch 51/100
# 20/20 [==============================] - 10s 499ms/step - loss: 2.4946e-06 - accuracy: 1.0000 - val_loss: 2.5362 - val_accuracy: 0.7460
# Epoch 52/100
# 20/20 [==============================] - 10s 494ms/step - loss: 2.4472e-06 - accuracy: 1.0000 - val_loss: 2.5457 - val_accuracy: 0.7460
# Epoch 53/100
# 20/20 [==============================] - 10s 493ms/step - loss: 2.3017e-06 - accuracy: 1.0000 - val_loss: 2.5502 - val_accuracy: 0.7450
# Epoch 54/100
# 20/20 [==============================] - 10s 497ms/step - loss: 2.2518e-06 - accuracy: 1.0000 - val_loss: 2.5551 - val_accuracy: 0.7450
# Epoch 55/100
# 20/20 [==============================] - 10s 495ms/step - loss: 2.1482e-06 - accuracy: 1.0000 - val_loss: 2.5631 - val_accuracy: 0.7480
# Epoch 56/100
# 20/20 [==============================] - 10s 495ms/step - loss: 1.9253e-06 - accuracy: 1.0000 - val_loss: 2.5677 - val_accuracy: 0.7440
# Epoch 57/100
# 20/20 [==============================] - 10s 497ms/step - loss: 1.7446e-06 - accuracy: 1.0000 - val_loss: 2.5751 - val_accuracy: 0.7470
# Epoch 58/100
# 20/20 [==============================] - 10s 508ms/step - loss: 1.8454e-06 - accuracy: 1.0000 - val_loss: 2.5790 - val_accuracy: 0.7470
# Epoch 59/100
# 20/20 [==============================] - 10s 496ms/step - loss: 1.7175e-06 - accuracy: 1.0000 - val_loss: 2.5913 - val_accuracy: 0.7480
# Epoch 60/100
# 20/20 [==============================] - 10s 493ms/step - loss: 1.5985e-06 - accuracy: 1.0000 - val_loss: 2.5941 - val_accuracy: 0.7470
# Epoch 61/100
# 20/20 [==============================] - 10s 496ms/step - loss: 1.5477e-06 - accuracy: 1.0000 - val_loss: 2.5981 - val_accuracy: 0.7470
# Epoch 62/100
# 20/20 [==============================] - 10s 496ms/step - loss: 1.4525e-06 - accuracy: 1.0000 - val_loss: 2.6022 - val_accuracy: 0.7480
# Epoch 63/100
# 20/20 [==============================] - 10s 497ms/step - loss: 1.4144e-06 - accuracy: 1.0000 - val_loss: 2.6098 - val_accuracy: 0.7460
# Epoch 64/100
# 20/20 [==============================] - 10s 492ms/step - loss: 1.3382e-06 - accuracy: 1.0000 - val_loss: 2.6145 - val_accuracy: 0.7460
# Epoch 65/100
# 20/20 [==============================] - 10s 492ms/step - loss: 1.2163e-06 - accuracy: 1.0000 - val_loss: 2.6191 - val_accuracy: 0.7450
# Epoch 66/100
# 20/20 [==============================] - 10s 495ms/step - loss: 1.2535e-06 - accuracy: 1.0000 - val_loss: 2.6272 - val_accuracy: 0.7470
# Epoch 67/100
# 20/20 [==============================] - 10s 500ms/step - loss: 1.2394e-06 - accuracy: 1.0000 - val_loss: 2.6295 - val_accuracy: 0.7460
# Epoch 68/100
# 20/20 [==============================] - 10s 501ms/step - loss: 1.1585e-06 - accuracy: 1.0000 - val_loss: 2.6351 - val_accuracy: 0.7470
# Epoch 69/100
# 20/20 [==============================] - 10s 499ms/step - loss: 1.1127e-06 - accuracy: 1.0000 - val_loss: 2.6417 - val_accuracy: 0.7470
# Epoch 70/100
# 20/20 [==============================] - 10s 498ms/step - loss: 1.1318e-06 - accuracy: 1.0000 - val_loss: 2.6458 - val_accuracy: 0.7470
# Epoch 71/100
# 20/20 [==============================] - 10s 503ms/step - loss: 1.0800e-06 - accuracy: 1.0000 - val_loss: 2.6493 - val_accuracy: 0.7470
# Epoch 72/100
# 20/20 [==============================] - 10s 504ms/step - loss: 1.0592e-06 - accuracy: 1.0000 - val_loss: 2.6563 - val_accuracy: 0.7470
# Epoch 73/100
# 20/20 [==============================] - 10s 499ms/step - loss: 9.6336e-07 - accuracy: 1.0000 - val_loss: 2.6599 - val_accuracy: 0.7480
# Epoch 74/100
# 20/20 [==============================] - 10s 501ms/step - loss: 9.3585e-07 - accuracy: 1.0000 - val_loss: 2.6646 - val_accuracy: 0.7470
# Epoch 75/100
# 20/20 [==============================] - 10s 499ms/step - loss: 8.7473e-07 - accuracy: 1.0000 - val_loss: 2.6708 - val_accuracy: 0.7450
# Epoch 76/100
# 20/20 [==============================] - 10s 501ms/step - loss: 8.4023e-07 - accuracy: 1.0000 - val_loss: 2.6731 - val_accuracy: 0.7470
# Epoch 77/100
# 20/20 [==============================] - 10s 505ms/step - loss: 8.9715e-07 - accuracy: 1.0000 - val_loss: 2.6774 - val_accuracy: 0.7470
# Epoch 78/100
# 20/20 [==============================] - 10s 508ms/step - loss: 8.3767e-07 - accuracy: 1.0000 - val_loss: 2.6808 - val_accuracy: 0.7460
# Epoch 79/100
# 20/20 [==============================] - 10s 501ms/step - loss: 8.1234e-07 - accuracy: 1.0000 - val_loss: 2.6882 - val_accuracy: 0.7460
# Epoch 80/100
# 20/20 [==============================] - 10s 502ms/step - loss: 7.8773e-07 - accuracy: 1.0000 - val_loss: 2.6913 - val_accuracy: 0.7460
# Epoch 81/100
# 20/20 [==============================] - 10s 503ms/step - loss: 7.5669e-07 - accuracy: 1.0000 - val_loss: 2.6951 - val_accuracy: 0.7470
# Epoch 82/100
# 20/20 [==============================] - 10s 506ms/step - loss: 6.0360e-07 - accuracy: 1.0000 - val_loss: 2.7005 - val_accuracy: 0.7470
# Epoch 83/100
# 20/20 [==============================] - 10s 506ms/step - loss: 7.1914e-07 - accuracy: 1.0000 - val_loss: 2.7024 - val_accuracy: 0.7450
# Epoch 84/100
# 20/20 [==============================] - 10s 509ms/step - loss: 6.7019e-07 - accuracy: 1.0000 - val_loss: 2.7093 - val_accuracy: 0.7440
# Epoch 85/100
# 20/20 [==============================] - 10s 505ms/step - loss: 6.2941e-07 - accuracy: 1.0000 - val_loss: 2.7112 - val_accuracy: 0.7470
# Epoch 86/100
# 20/20 [==============================] - 10s 507ms/step - loss: 6.7885e-07 - accuracy: 1.0000 - val_loss: 2.7171 - val_accuracy: 0.7470
# Epoch 87/100
# 20/20 [==============================] - 10s 511ms/step - loss: 6.4478e-07 - accuracy: 1.0000 - val_loss: 2.7219 - val_accuracy: 0.7460
# Epoch 88/100
# 20/20 [==============================] - 10s 510ms/step - loss: 5.7132e-07 - accuracy: 1.0000 - val_loss: 2.7236 - val_accuracy: 0.7470
# Epoch 89/100
# 20/20 [==============================] - 10s 506ms/step - loss: 6.2647e-07 - accuracy: 1.0000 - val_loss: 2.7275 - val_accuracy: 0.7470
# Epoch 90/100
# 20/20 [==============================] - 10s 507ms/step - loss: 5.9147e-07 - accuracy: 1.0000 - val_loss: 2.7326 - val_accuracy: 0.7460
# Epoch 91/100
# 20/20 [==============================] - 10s 507ms/step - loss: 5.5115e-07 - accuracy: 1.0000 - val_loss: 2.7337 - val_accuracy: 0.7460
# Epoch 92/100
# 20/20 [==============================] - 10s 508ms/step - loss: 5.2341e-07 - accuracy: 1.0000 - val_loss: 2.7399 - val_accuracy: 0.7490
# Epoch 93/100
# 20/20 [==============================] - 10s 508ms/step - loss: 5.0288e-07 - accuracy: 1.0000 - val_loss: 2.7427 - val_accuracy: 0.7460
# Epoch 94/100
# 20/20 [==============================] - 10s 505ms/step - loss: 5.2266e-07 - accuracy: 1.0000 - val_loss: 2.7483 - val_accuracy: 0.7460
# Epoch 95/100
# 20/20 [==============================] - 10s 506ms/step - loss: 4.9028e-07 - accuracy: 1.0000 - val_loss: 2.7521 - val_accuracy: 0.7470
# Epoch 96/100
# 20/20 [==============================] - 10s 506ms/step - loss: 4.7576e-07 - accuracy: 1.0000 - val_loss: 2.7551 - val_accuracy: 0.7460
# Epoch 97/100
# 20/20 [==============================] - 10s 514ms/step - loss: 4.6692e-07 - accuracy: 1.0000 - val_loss: 2.7567 - val_accuracy: 0.7500
# Epoch 98/100
# 20/20 [==============================] - 10s 506ms/step - loss: 4.6504e-07 - accuracy: 1.0000 - val_loss: 2.7614 - val_accuracy: 0.7470
# Epoch 99/100
# 20/20 [==============================] - 10s 504ms/step - loss: 4.1274e-07 - accuracy: 1.0000 - val_loss: 2.7641 - val_accuracy: 0.7500
# Epoch 100/100
# 20/20 [==============================] - 10s 506ms/step - loss: 4.7260e-07 - accuracy: 1.0000 - val_loss: 2.7684 - val_accuracy: 0.7500

# %% [markdown]
# # Visualising the data

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.savefig('./foo.png')
plt.show()
